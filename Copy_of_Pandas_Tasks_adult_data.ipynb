# %%
import pandas as pd

# %% [markdown]
# read the data

# %%
dataset=pd.read_csv('/content/adult.csv')
dataset
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18          ?  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 28850   25    Private   66935       HS-grad                9
# 28851   20    Private  344278          11th                7
# 28852   29    Private  108574     Assoc-voc               11
# 28853   56    Private  244605       HS-grad                9
# 28854   45    Private  363677     Doctorate               16
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4           Never-married                  ?      Own-child  White  Female
# ...                   ...                ...            ...    ...     ...
# 28850       Never-married       Craft-repair  Not-in-family  White    Male
# 28851           Separated      Other-service      Own-child  White  Female
# 28852       Never-married    Priv-house-serv      Own-child  White  Female
# 28853  Married-civ-spouse       Craft-repair        Husband  White    Male
# 28854                  Ma                NaN            NaN    NaN     NaN
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0               0.0           0.0            40.0  United-States  <=50K
# 1               0.0           0.0            50.0  United-States  <=50K
# 2               0.0           0.0            40.0  United-States   >50K
# 3            7688.0           0.0            40.0  United-States   >50K
# 4               0.0           0.0            30.0  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 28850           0.0           0.0            35.0  United-States  <=50K
# 28851           0.0           0.0            40.0  United-States  <=50K
# 28852           0.0           0.0            40.0  United-States  <=50K
# 28853           0.0           0.0            40.0  United-States  <=50K
# 28854           NaN           NaN             NaN            NaN    NaN
#
# [28855 rows x 15 columns]

# %% [markdown]
# Display the first 5 rows of the dataset.

# %%
dataset.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male           0.0           0.0
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 2    Protective-serv      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                  ?    Own-child  White  Female           0.0           0.0
#
#    hours-per-week native-country income
# 0            40.0  United-States  <=50K
# 1            50.0  United-States  <=50K
# 2            40.0  United-States   >50K
# 3            40.0  United-States   >50K
# 4            30.0  United-States  <=50K

# %% [markdown]
# summary of the DataFrame

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28855 entries, 0 to 28854
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              28855 non-null  int64
#  1   workclass        28855 non-null  object
#  2   fnlwgt           28855 non-null  int64
#  3   education        28855 non-null  object
#  4   educational-num  28855 non-null  int64
#  5   marital-status   28855 non-null  object
#  6   occupation       28854 non-null  object
#  7   relationship     28854 non-null  object
#  8   race             28854 non-null  object
#  9   gender           28854 non-null  object
#  10  capital-gain     28854 non-null  float64
#  11  capital-loss     28854 non-null  float64
#  12  hours-per-week   28854 non-null  float64
#  13  native-country   28854 non-null  object
#  14  income           28854 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 3.3+ MB

# %% [markdown]
# descriptive statistics for numeric columns

# %%
dataset.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  28855.000000  2.885500e+04     28855.000000  28854.000000
# mean      38.634344  1.897565e+05        10.073575   1070.827892
# std       13.742880  1.054501e+05         2.559413   7463.025745
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.175270e+05         9.000000      0.000000
# 50%       37.000000  1.781090e+05        10.000000      0.000000
# 75%       48.000000  2.384100e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  28854.000000    28854.000000
# mean      88.328273       40.442608
# std      403.260391       12.384877
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# Display the column names of the DataFrame.

# %%
dataset.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %% [markdown]
# unique values in the 'workclass' column.

# %%
dataset.workclass.unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %% [markdown]
# Create a new column 'income_binary' where <=50K is 0 and >50K is 1.

# %%
dataset['income_binary'] = dataset['income'].apply(lambda x: 0 if x == '<=50K' else 1)
dataset
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18          ?  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 28850   25    Private   66935       HS-grad                9
# 28851   20    Private  344278          11th                7
# 28852   29    Private  108574     Assoc-voc               11
# 28853   56    Private  244605       HS-grad                9
# 28854   45    Private  363677     Doctorate               16
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4           Never-married                  ?      Own-child  White  Female
# ...                   ...                ...            ...    ...     ...
# 28850       Never-married       Craft-repair  Not-in-family  White    Male
# 28851           Separated      Other-service      Own-child  White  Female
# 28852       Never-married    Priv-house-serv      Own-child  White  Female
# 28853  Married-civ-spouse       Craft-repair        Husband  White    Male
# 28854                  Ma                NaN            NaN    NaN     NaN
#
#        capital-gain  capital-loss  hours-per-week native-country income  \
# 0               0.0           0.0            40.0  United-States  <=50K
# 1               0.0           0.0            50.0  United-States  <=50K
# 2               0.0           0.0            40.0  United-States   >50K
# 3            7688.0           0.0            40.0  United-States   >50K
# 4               0.0           0.0            30.0  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 28850           0.0           0.0            35.0  United-States  <=50K
# 28851           0.0           0.0            40.0  United-States  <=50K
# 28852           0.0           0.0            40.0  United-States  <=50K
# 28853           0.0           0.0            40.0  United-States  <=50K
# 28854           NaN           NaN             NaN            NaN    NaN
#
#        income_binary
# 0                  0
# 1                  0
# 2                  1
# 3                  1
# 4                  0
# ...              ...
# 28850              0
# 28851              0
# 28852              0
# 28853              0
# 28854              1
#
# [28855 rows x 16 columns]

# %% [markdown]
# Create a new column 'age_group' categorizing ages into 'Youth' (< 30), 'Adult' (30-60), and 'Senior' (60+).

# %%
dataset['age_group'] = pd.cut(dataset['age'], bins=[0, 30, 60, float('inf')], labels=['Youth', 'Adult', 'Senior'])
dataset
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18          ?  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 28850   25    Private   66935       HS-grad                9
# 28851   20    Private  344278          11th                7
# 28852   29    Private  108574     Assoc-voc               11
# 28853   56    Private  244605       HS-grad                9
# 28854   45    Private  363677     Doctorate               16
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4           Never-married                  ?      Own-child  White  Female
# ...                   ...                ...            ...    ...     ...
# 28850       Never-married       Craft-repair  Not-in-family  White    Male
# 28851           Separated      Other-service      Own-child  White  Female
# 28852       Never-married    Priv-house-serv      Own-child  White  Female
# 28853  Married-civ-spouse       Craft-repair        Husband  White    Male
# 28854                  Ma                NaN            NaN    NaN     NaN
#
#        capital-gain  capital-loss  hours-per-week native-country income  \
# 0               0.0           0.0            40.0  United-States  <=50K
# 1               0.0           0.0            50.0  United-States  <=50K
# 2               0.0           0.0            40.0  United-States   >50K
# 3            7688.0           0.0            40.0  United-States   >50K
# 4               0.0           0.0            30.0  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 28850           0.0           0.0            35.0  United-States  <=50K
# 28851           0.0           0.0            40.0  United-States  <=50K
# 28852           0.0           0.0            40.0  United-States  <=50K
# 28853           0.0           0.0            40.0  United-States  <=50K
# 28854           NaN           NaN             NaN            NaN    NaN
#
#        income_binary age_group
# 0                  0     Youth
# 1                  0     Adult
# 2                  1     Youth
# 3                  1     Adult
# 4                  0     Youth
# ...              ...       ...
# 28850              0     Youth
# 28851              0     Youth
# 28852              0     Youth
# 28853              0     Adult
# 28854              1     Adult
#
# [28855 rows x 17 columns]

# %% [markdown]
# Rename the 'educational-num' column to 'education_num'.

# %%
dataset.rename(columns={'educational-num': 'education_num'}, inplace=True)
dataset
# Out:
#        age  workclass  fnlwgt     education  education_num  \
# 0       25    Private  226802          11th              7
# 1       38    Private   89814       HS-grad              9
# 2       28  Local-gov  336951    Assoc-acdm             12
# 3       44    Private  160323  Some-college             10
# 4       18          ?  103497  Some-college             10
# ...    ...        ...     ...           ...            ...
# 28850   25    Private   66935       HS-grad              9
# 28851   20    Private  344278          11th              7
# 28852   29    Private  108574     Assoc-voc             11
# 28853   56    Private  244605       HS-grad              9
# 28854   45    Private  363677     Doctorate             16
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4           Never-married                  ?      Own-child  White  Female
# ...                   ...                ...            ...    ...     ...
# 28850       Never-married       Craft-repair  Not-in-family  White    Male
# 28851           Separated      Other-service      Own-child  White  Female
# 28852       Never-married    Priv-house-serv      Own-child  White  Female
# 28853  Married-civ-spouse       Craft-repair        Husband  White    Male
# 28854                  Ma                NaN            NaN    NaN     NaN
#
#        capital-gain  capital-loss  hours-per-week native-country income  \
# 0               0.0           0.0            40.0  United-States  <=50K
# 1               0.0           0.0            50.0  United-States  <=50K
# 2               0.0           0.0            40.0  United-States   >50K
# 3            7688.0           0.0            40.0  United-States   >50K
# 4               0.0           0.0            30.0  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 28850           0.0           0.0            35.0  United-States  <=50K
# 28851           0.0           0.0            40.0  United-States  <=50K
# 28852           0.0           0.0            40.0  United-States  <=50K
# 28853           0.0           0.0            40.0  United-States  <=50K
# 28854           NaN           NaN             NaN            NaN    NaN
#
#        income_binary age_group
# 0                  0     Youth
# 1                  0     Adult
# 2                  1     Youth
# 3                  1     Adult
# 4                  0     Youth
# ...              ...       ...
# 28850              0     Youth
# 28851              0     Youth
# 28852              0     Youth
# 28853              0     Adult
# 28854              1     Adult
#
# [28855 rows x 17 columns]

# %% [markdown]
# Replace the missing values represented by '?' in 'workclass' and 'occupation' columns with 'Unknown'.

# %%
Calculate the average age for each workclass.

# %%
dataset.groupby('workclass')['age'].mean()
# Out:
# workclass
# ?                   39.274926
# Federal-gov         42.318072
# Local-gov           41.662690
# Never-worked        19.200000
# Private             36.964008
# Self-emp-inc        45.387129
# Self-emp-not-inc    45.432292
# State-gov           39.583954
# Without-pay         45.333333
# Name: age, dtype: float64

# %% [markdown]
# Find the total capital-gain for each gender.

# %%
dataset.groupby('gender')['capital-gain'].sum()
# Out:
# gender
# Female     5704885.0
# Male      25192783.0
# Name: capital-gain, dtype: float64

# %% [markdown]
# Get the count of each marital-status category.

# %%
dataset['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       13174
# Never-married             9549
# Divorced                  3927
# Separated                  912
# Widowed                    889
# Married-spouse-absent      380
# Married-AF-spouse           23
# Ma                           1
# Name: count, dtype: int64

# %% [markdown]
# Find the mean hours-per-week worked by individuals in different education levels.

# %%
dataset.groupby('education')['hours-per-week'].mean()
# Out:
# education
# 10th            37.652387
# 11th            34.269549
# 12th            34.407713
# 1st-4th         38.821429
# 5th-6th         39.494949
# 7th-8th         39.115453
# 9th             38.383721
# Assoc-acdm      41.126350
# Assoc-voc       41.532718
# Bachelors       42.370527
# Doctorate       46.253776
# HS-grad         40.671531
# Masters         43.418590
# Preschool       36.576923
# Prof-school     48.251599
# Some-college    38.894159
# Name: hours-per-week, dtype: float64

# %% [markdown]
# Calculate the mean, median, and standard deviation of 'fnlwgt' for each race.

# %%
dataset.groupby('race')['fnlwgt'].agg(['mean', 'median', 'std'])
# Out:
#                              mean    median            std
# race
# Amer-Indian-Eskimo  121731.661818  108765.0  100337.774841
# Asian-Pac-Islander  159856.569444  139012.0   87768.812310
# Black               232467.644203  210959.0  128375.607520
# Other               196191.763948  182360.0   99052.249563
# White               186722.138702  177132.5  101831.666656

# %% [markdown]
# Get the unique values and their counts for the 'native-country' column

# %%
dataset['native-country'].value_counts()
# Out:
# native-country
# United-States                 25915
# Mexico                          552
# ?                               497
# Philippines                     166
# Germany                         127
# Puerto-Rico                     123
# Canada                          114
# India                            87
# El-Salvador                      87
# China                            81
# Cuba                             79
# England                          73
# South                            70
# Jamaica                          61
# Dominican-Republic               59
# Italy                            59
# Poland                           54
# Japan                            52
# Haiti                            50
# Guatemala                        49
# Vietnam                          46
# Portugal                         46
# Columbia                         41
# Iran                             39
# Greece                           38
# Taiwan                           36
# Nicaragua                        27
# Ecuador                          27
# Peru                             25
# Ireland                          24
# Thailand                         20
# Cambodia                         18
# France                           16
# Trinadad&Tobago                  15
# Hong                             14
# Honduras                         13
# Outlying-US(Guam-USVI-etc)       13
# Scotland                         12
# Yugoslavia                       12
# Laos                              9
# Hungary                           8
# Name: count, dtype: int64

# %% [markdown]
# Filter the dataset to include only individuals with income >50K.

# %%
dataset[dataset['income'] == '>50K']
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 2       28         Local-gov  336951    Assoc-acdm             12
# 3       44           Private  160323  Some-college             10
# 7       63  Self-emp-not-inc  104626   Prof-school             15
# 10      65           Private  184454       HS-grad              9
# 14      48           Private  279724       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 28845   64           Private  391121       7th-8th              4
# 28846   42           Private  211450       Masters             14
# 28847   44           Private  156413  Some-college             10
# 28848   41           Private  116797       HS-grad              9
# 28849   53         Local-gov  204447       Masters             14
#
#            marital-status         occupation   relationship   race gender  \
# 2      Married-civ-spouse    Protective-serv        Husband  White   Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black   Male
# 7      Married-civ-spouse     Prof-specialty        Husband  White   Male
# 10     Married-civ-spouse  Machine-op-inspct        Husband  White   Male
# 14     Married-civ-spouse  Machine-op-inspct        Husband  White   Male
# ...                   ...                ...            ...    ...    ...
# 28845  Married-civ-spouse    Farming-fishing        Husband  White   Male
# 28846       Never-married    Exec-managerial  Not-in-family  White   Male
# 28847  Married-civ-spouse       Tech-support        Husband  White   Male
# 28848  Married-civ-spouse              Sales        Husband  White   Male
# 28849  Married-civ-spouse    Exec-managerial        Husband  White   Male
#
#        capital-gain  capital-loss  hours-per-week native-country income  \
# 2               0.0           0.0            40.0  United-States   >50K
# 3            7688.0           0.0            40.0  United-States   >50K
# 7            3103.0           0.0            32.0  United-States   >50K
# 10           6418.0           0.0            40.0  United-States   >50K
# 14           3103.0           0.0            48.0  United-States   >50K
# ...             ...           ...             ...            ...    ...
# 28845           0.0           0.0            40.0  United-States   >50K
# 28846           0.0           0.0            45.0  United-States   >50K
# 28847           0.0           0.0            44.0  United-States   >50K
# 28848        7298.0           0.0            50.0  United-States   >50K
# 28849           0.0           0.0            43.0  United-States   >50K
#
#        income_binary age_group
# 2                  1     Youth
# 3                  1     Adult
# 7                  1    Senior
# 10                 1    Senior
# 14                 1     Adult
# ...              ...       ...
# 28845              1    Senior
# 28846              1     Adult
# 28847              1     Adult
# 28848              1     Adult
# 28849              1     Adult
#
# [6855 rows x 17 columns]

# %% [markdown]
# Sort the dataset by age in descending order.

# %%
dataset.sort_values(by='age', ascending=False)
# Out:
#        age workclass  fnlwgt  education  education_num      marital-status  \
# 20390   90         ?  256514  Bachelors             13             Widowed
# 22905   90   Private  313986       11th              7  Married-civ-spouse
# 17321   90   Private  137018    HS-grad              9       Never-married
# 26826   90   Private  175491    HS-grad              9  Married-civ-spouse
# 20351   90   Private  313986       11th              7       Never-married
# ...    ...       ...     ...        ...            ...                 ...
# 26576   17   Private  228399       11th              7       Never-married
# 17121   17   Private  198124       11th              7       Never-married
# 17095   17   Private   32607       10th              6       Never-married
# 17085   17   Private  193830       11th              7       Never-married
# 7877    17   Private  284277       11th              7       Never-married
#
#               occupation    relationship   race  gender  capital-gain  \
# 20390                  ?  Other-relative  White  Female         991.0
# 22905       Craft-repair         Husband  White    Male           0.0
# 17321      Other-service   Not-in-family  White  Female           0.0
# 26826       Craft-repair         Husband  White    Male        9386.0
# 20351  Handlers-cleaners       Own-child  White    Male           0.0
# ...                  ...             ...    ...     ...           ...
# 26576      Other-service       Own-child  White  Female           0.0
# 17121              Sales       Own-child  White    Male           0.0
# 17095    Farming-fishing       Own-child  White    Male           0.0
# 17085              Sales       Own-child  White  Female           0.0
# 7877       Other-service       Own-child  White    Male        1055.0
#
#        capital-loss  hours-per-week native-country income  income_binary  \
# 20390           0.0            10.0  United-States  <=50K              0
# 22905           0.0            40.0  United-States  <=50K              0
# 17321           0.0            40.0  United-States  <=50K              0
# 26826           0.0            50.0        Ecuador   >50K              1
# 20351           0.0            40.0  United-States  <=50K              0
# ...             ...             ...            ...    ...            ...
# 26576           0.0             7.0  United-States  <=50K              0
# 17121           0.0            20.0  United-States  <=50K              0
# 17095           0.0            20.0  United-States  <=50K              0
# 17085           0.0            20.0  United-States  <=50K              0
# 7877            0.0            20.0  United-States  <=50K              0
#
#       age_group
# 20390    Senior
# 22905    Senior
# 17321    Senior
# 26826    Senior
# 20351    Senior
# ...         ...
# 26576     Youth
# 17121     Youth
# 17095     Youth
# 17085     Youth
# 7877      Youth
#
# [28855 rows x 17 columns]

# %% [markdown]
# Filter the dataset to include only individuals who work more than 40 hours per week.

# %%
dataset[dataset['hours-per-week'] > 40]
# Out:
#        age  workclass  fnlwgt     education  education_num  \
# 1       38    Private   89814       HS-grad              9
# 14      48    Private  279724       HS-grad              9
# 15      43    Private  346189       Masters             14
# 19      40    Private   85019     Doctorate             16
# 20      34    Private  107914     Bachelors             13
# ...    ...        ...     ...           ...            ...
# 28838   34    Private  191834     Assoc-voc             11
# 28846   42    Private  211450       Masters             14
# 28847   44    Private  156413  Some-college             10
# 28848   41    Private  116797       HS-grad              9
# 28849   53  Local-gov  204447       Masters             14
#
#            marital-status         occupation   relationship  \
# 1      Married-civ-spouse    Farming-fishing        Husband
# 14     Married-civ-spouse  Machine-op-inspct        Husband
# 15     Married-civ-spouse    Exec-managerial        Husband
# 19     Married-civ-spouse     Prof-specialty        Husband
# 20     Married-civ-spouse       Tech-support        Husband
# ...                   ...                ...            ...
# 28838  Married-civ-spouse       Craft-repair        Husband
# 28846       Never-married    Exec-managerial  Not-in-family
# 28847  Married-civ-spouse       Tech-support        Husband
# 28848  Married-civ-spouse              Sales        Husband
# 28849  Married-civ-spouse    Exec-managerial        Husband
#
#                      race gender  capital-gain  capital-loss  hours-per-week  \
# 1                   White   Male           0.0           0.0            50.0
# 14                  White   Male        3103.0           0.0            48.0
# 15                  White   Male           0.0           0.0            50.0
# 19     Asian-Pac-Islander   Male           0.0           0.0            45.0
# 20                  White   Male           0.0           0.0            47.0
# ...                   ...    ...           ...           ...             ...
# 28838               White   Male           0.0           0.0            48.0
# 28846               White   Male           0.0           0.0            45.0
# 28847               White   Male           0.0           0.0            44.0
# 28848               White   Male        7298.0           0.0            50.0
# 28849               White   Male           0.0           0.0            43.0
#
#       native-country income  income_binary age_group
# 1      United-States  <=50K              0     Adult
# 14     United-States   >50K              1     Adult
# 15     United-States   >50K              1     Adult
# 19                 ?   >50K              1     Adult
# 20     United-States   >50K              1     Adult
# ...              ...    ...            ...       ...
# 28838  United-States  <=50K              0     Adult
# 28846  United-States   >50K              1     Adult
# 28847  United-States   >50K              1     Adult
# 28848  United-States   >50K              1     Adult
# 28849  United-States   >50K              1     Adult
#
# [8487 rows x 17 columns]

# %%
Calculate the percentage of missing values in each column.

# %%
dataset.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital-status    0
# occupation        1
# relationship      1
# race              1
# gender            1
# capital-gain      1
# capital-loss      1
# hours-per-week    1
# native-country    1
# income            1
# income_binary     0
# age_group         0
# dtype: int64

# %% [markdown]
# Calculate the median income by education level and gender.

# %%
dataset.groupby(['education', 'gender'])['income_binary'].median()
# Out:
# education     gender
# 10th          Female    0.0
#               Male      0.0
# 11th          Female    0.0
#               Male      0.0
# 12th          Female    0.0
#               Male      0.0
# 1st-4th       Female    0.0
#               Male      0.0
# 5th-6th       Female    0.0
#               Male      0.0
# 7th-8th       Female    0.0
#               Male      0.0
# 9th           Female    0.0
#               Male      0.0
# Assoc-acdm    Female    0.0
#               Male      0.0
# Assoc-voc     Female    0.0
#               Male      0.0
# Bachelors     Female    0.0
#               Male      0.0
# Doctorate     Female    1.0
#               Male      1.0
# HS-grad       Female    0.0
#               Male      0.0
# Masters       Female    0.0
#               Male      1.0
# Preschool     Female    0.0
#               Male      0.0
# Prof-school   Female    0.0
#               Male      1.0
# Some-college  Female    0.0
#               Male      0.0
# Name: income_binary, dtype: float64

# %% [markdown]
# Find the top 3 occupations with the highest average capital-gain.

# %%
dataset.groupby('occupation')['capital-gain'].mean().nlargest(3)
# Out:
# occupation
# Prof-specialty     2865.008306
# Exec-managerial    2153.967606
# Sales              1220.093960
# Name: capital-gain, dtype: float64

# %% [markdown]
# Filter the dataset to include individuals who are 'Married-civ-spouse' and have an income >50K.

# %%
dataset[(dataset['marital-status'] == 'Married-civ-spouse') & (dataset['income'] == '>50K')]
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 2       28         Local-gov  336951    Assoc-acdm             12
# 3       44           Private  160323  Some-college             10
# 7       63  Self-emp-not-inc  104626   Prof-school             15
# 10      65           Private  184454       HS-grad              9
# 14      48           Private  279724       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 28841   34           Private  303187     Bachelors             13
# 28845   64           Private  391121       7th-8th              4
# 28847   44           Private  156413  Some-college             10
# 28848   41           Private  116797       HS-grad              9
# 28849   53         Local-gov  204447       Masters             14
#
#            marital-status         occupation relationship                race  \
# 2      Married-civ-spouse    Protective-serv      Husband               White
# 3      Married-civ-spouse  Machine-op-inspct      Husband               Black
# 7      Married-civ-spouse     Prof-specialty      Husband               White
# 10     Married-civ-spouse  Machine-op-inspct      Husband               White
# 14     Married-civ-spouse  Machine-op-inspct      Husband               White
# ...                   ...                ...          ...                 ...
# 28841  Married-civ-spouse     Prof-specialty      Husband  Asian-Pac-Islander
# 28845  Married-civ-spouse    Farming-fishing      Husband               White
# 28847  Married-civ-spouse       Tech-support      Husband               White
# 28848  Married-civ-spouse              Sales      Husband               White
# 28849  Married-civ-spouse    Exec-managerial      Husband               White
#
#       gender  capital-gain  capital-loss  hours-per-week native-country  \
# 2       Male           0.0           0.0            40.0  United-States
# 3       Male        7688.0           0.0            40.0  United-States
# 7       Male        3103.0           0.0            32.0  United-States
# 10      Male        6418.0           0.0            40.0  United-States
# 14      Male        3103.0           0.0            48.0  United-States
# ...      ...           ...           ...             ...            ...
# 28841   Male           0.0           0.0            40.0              ?
# 28845   Male           0.0           0.0            40.0  United-States
# 28847   Male           0.0           0.0            44.0  United-States
# 28848   Male        7298.0           0.0            50.0  United-States
# 28849   Male           0.0           0.0            43.0  United-States
#
#       income  income_binary age_group
# 2       >50K              1     Youth
# 3       >50K              1     Adult
# 7       >50K              1    Senior
# 10      >50K              1    Senior
# 14      >50K              1     Adult
# ...      ...            ...       ...
# 28841   >50K              1     Adult
# 28845   >50K              1    Senior
# 28847   >50K              1     Adult
# 28848   >50K              1     Adult
# 28849   >50K              1     Adult
#
# [5861 rows x 17 columns]
